# %% [markdown]
# Membuat array

# %%
import array as arr

nilai = arr.array('i', [80, 85, 90, 75])
print(nilai)
# Out:
# array('i', [80, 85, 90, 75])

# %% [markdown]
# Menambahkan elemen array

# %%
import array as arr

nilai = arr.array('i', [80, 85, 90, 75])
print("Array awal:", nilai)

nilai.append(88)
print("Setelah append 88:", nilai)

nilai.insert(1, 95)
print("Setelah insert 95 di indeks 1:", nilai)
# Out:
# Array awal: array('i', [80, 85, 90, 75])
# Setelah append 88: array('i', [80, 85, 90, 75, 88])
# Setelah insert 95 di indeks 1: array('i', [80, 95, 85, 90, 75, 88])

# %% [markdown]
# Mengakses elemen array

# %%
import array as arr

nilai = arr.array('i', [80, 85, 90, 75])

# print("Array:", nilai)
print("Elemen pertama:", nilai[0])
print("Elemen keempat:", nilai[3])
# Out:
# Elemen pertama: 80
# Elemen keempat: 75

# %% [markdown]
# Menghapus elemen array

# %%
import array as arr

nilai = arr.array('i', [80, 85, 90, 75, 88])
print("Array awal:", nilai)

nilai.remove(85)
print("Setelah remove 85:", nilai)

nilai.pop()
print("Setelah pop():", nilai)
# Out:
# Array awal: array('i', [80, 85, 90, 75, 88])
# Setelah remove 85: array('i', [80, 90, 75, 88])
# Setelah pop(): array('i', [80, 90, 75])

# %% [markdown]
# Slicing atau pemotongan elemen array

# %%
import array as arr

nilai = arr.array('i', [80, 85, 90, 75, 88])
print("Array awal:", nilai)

print("Slicing indeks 1 sampai 4:", nilai[1:4])
print("Dari awal sampai indeks 3:", nilai[:3])
print("Dibalik:", nilai[::-1])
# Out:
# Array awal: array('i', [80, 85, 90, 75, 88])
# Slicing indeks 1 sampai 4: array('i', [85, 90, 75])
# Dari awal sampai indeks 3: array('i', [80, 85, 90])
# Dibalik: array('i', [88, 75, 90, 85, 80])

# %% [markdown]
# Mengubah elemen array

# %%
import array as arr

nilai = arr.array('i', [80, 85, 90, 75])
print("Array awal:", nilai)

nilai[0] = 100
nilai[2] = 95

print("Setelah perubahan:", nilai)
# Out:
# Array awal: array('i', [80, 85, 90, 75])
# Setelah perubahan: array('i', [100, 85, 95, 75])

# %% [markdown]
# Operasi tambahan array

# %%
import array as arr

nilai = arr.array('i', [80, 90, 75, 90])
print("Array awal:", nilai)

print("Jumlah angka 90:", nilai.count(90))

nilai.reverse()
print("Setelah reverse:", nilai)

nilai.extend([70, 60])
print("Setelah extend:", nilai)
# Out:
# Array awal: array('i', [80, 90, 75, 90])
# Jumlah angka 90: 2
# Setelah reverse: array('i', [90, 75, 90, 80])
# Setelah extend: array('i', [90, 75, 90, 80, 70, 60])
